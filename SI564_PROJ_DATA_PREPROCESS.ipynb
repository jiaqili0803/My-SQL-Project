# %%
# preprocessing the genre id

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('original_data.csv')

# %%
df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %%
np.max(df['IMDB Score'])
# Out:
# 9.0

# %%
np.min(df['IMDB Score'])
# Out:
# 2.5

# %%
plt.hist(df["IMDB Score"])

# Add chart title and axis labels
plt.title("IMDB Score Distribution")
plt.xlabel("Score")
plt.ylabel("Count")

# Display the chart
plt.show()

# %%
unique_genres = sorted(df['Genre'].unique())
genre_to_id = {genre: idx for idx, genre in enumerate(unique_genres)}
df['Genre_id'] = df['Genre'].map(genre_to_id)

# %%
df.to_csv('updated_genre_talbe.csv', index=False)

# %%
df
# Out:
#      movie_id  Unnamed: 1                  Genre  Genre_id
# 0           1         NaN            Documentary        45
# 1           2         NaN               Thriller       106
# 2           3         NaN  Science fiction/Drama        93
# 3           4         NaN        Horror thriller        63
# 4           5         NaN                Mystery        73
# ..        ...         ...                    ...       ...
# 579       580         NaN           Concert Film        40
# 580       581         NaN            Documentary        45
# 581       582         NaN           One-man show        74
# 582       583         NaN            Documentary        45
# 583       584         NaN            Documentary        45
#
# [584 rows x 4 columns]

# %%
print('there are in total: ', max(df['Genre_id']), 'genres')
# Out:
# there are in total:  114 genres

# %%
# preprocessing language table

# %%
df = pd.read_csv('NetflixOriginals——language.csv')

# %%
df
# Out:
#      movie_id                  Language
# 0           1          English/Japanese
# 1           2                   Spanish
# 2           3                   Italian
# 3           4                   English
# 4           5                     Hindi
# ..        ...                       ...
# 579       580                   English
# 580       581  English/Ukranian/Russian
# 581       582                   English
# 582       583                Portuguese
# 583       584                   English
#
# [584 rows x 2 columns]

# %%
unique_lan = sorted(df['Language'].unique())
lan_to_id = {lan: idx for idx, lan in enumerate(unique_lan)}
df['Language_id'] = df['Language'].map(lan_to_id)

# %%
df
# Out:
#      movie_id                  Language  Language_id
# 0           1          English/Japanese            6
# 1           2                   Spanish           29
# 2           3                   Italian           20
# 3           4                   English            2
# 4           5                     Hindi           18
# ..        ...                       ...          ...
# 579       580                   English            2
# 580       581  English/Ukranian/Russian           13
# 581       582                   English            2
# 582       583                Portuguese           28
# 583       584                   English            2
#
# [584 rows x 3 columns]

# %%
df.to_csv('updated_lan_table.csv', index=False)

# %%
print('there are in total: ', max(df['Language_id']), 'languages')
# Out:
# there are in total:  37 languages

# %%
############### TODO

# %% [markdown]
# I plan to use SQL queries to extract insights on movie trends, such as popular genres and
# languages, and their correlation with IMDB scores. I will also investigate the relationship
# between premiere dates and movie success to optimize release strategies. Lastly, I may
# analyze runtime data to determine the optimal content duration for different genres and
# languages

# %%
###############################

# %%
df = pd.read_csv('languages.csv')

# %%
df
# Out:
#      Language_id                  Language
# 0              6          English/Japanese
# 1             29                   Spanish
# 2             20                   Italian
# 3              2                   English
# 4             18                     Hindi
# ..           ...                       ...
# 579            2                   English
# 580           13  English/Ukranian/Russian
# 581            2                   English
# 582           28                Portuguese
# 583            2                   English
#
# [584 rows x 2 columns]

# %%
df = df.drop_duplicates(subset=['Language_id'])

# %%
df
# Out:
#      Language_id                    Language
# 0              6            English/Japanese
# 1             29                     Spanish
# 2             20                     Italian
# 3              2                     English
# 4             18                       Hindi
# 6             37                     Turkish
# 11            23                      Korean
# 12            19                  Indonesian
# 13            24                       Malay
# 26             1                       Dutch
# 28            15                      French
# 30            10             English/Spanish
# 33            28                  Portuguese
# 37            14                    Filipino
# 43            17                      German
# 46            27                      Polish
# 59            26                   Norwegian
# 70            25                     Marathi
# 71            35                        Thai
# 117           33                     Swedish
# ...

# %%
df.to_csv('uniques_language.csv', index=False)
